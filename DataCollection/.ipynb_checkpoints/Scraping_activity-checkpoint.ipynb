# %% [markdown]
# ## Activity:-
# ### From Quotes, extract all quotes & outcomes from all pages with the life tag.
# #### website link:-  https://quotes.toscrape.com

# %%
import requests

from bs4 import BeautifulSoup

# %%
# Fetch data & store it

page_count = 1

while True:
    URL = f"https://quotes.toscrape.com/page/{page_count}/"
    res = requests.get(URL)

    soup = BeautifulSoup(res.text, "lxml")
    quotes = soup.select("div.quote")

    if not quotes:
        print("no valid pages anymore..")
        break

    with open(f"scraped_data/quotes{page_count}.html", "w") as f:
        f.write(res.text)
        print(f"download data from page {page_count}")
        
    page_count = page_count + 1
# Out:
# download data from page 1
# download data from page 2
# download data from page 3
# download data from page 4
# download data from page 5
# download data from page 6
# download data from page 7
# download data from page 8
# download data from page 9
# download data from page 10
# no valid pages anymore..

# %%
# Extract useful info_page1

with open("scraped_data/quotes1.html", "r") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "lxml")

# %%
all_quotes = soup.select("div.quote")
life_quotes = []

for q in all_quotes:
    all_tags = []

    for tag in q.select(".tags .tag"): all_tags.append(tag.get_text())

    if "life" in all_tags:
        text = q.select_one("span.text").get_text()
        author = q.select_one("small.author").get_text()

        life_quotes.append([text, author])

print(life_quotes)
# Out:
# [['“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”', 'Albert Einstein'], ['“It is better to be hated for what you are than to be loved for what you are not.”', 'André Gide']]
