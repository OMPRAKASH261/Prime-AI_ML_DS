# %%
import pandas as pd

# %%
# Dataframe
info = {
    "Name" : ["Rahul", "Vijay", "kavya"],
    "CGPA" : [9.4, 8.3, 9.0]
}

df = pd.DataFrame(info)

print(df)
# Out:
#     Name  CGPA
# 0  Rahul   9.4
# 1  Vijay   8.3
# 2  kavya   9.0

# %%
df
# Out:
#     Name  CGPA
# 0  Rahul   9.4
# 1  Vijay   8.3
# 2  kavya   9.0
